# %% [markdown]
# # Masking
#
# The idea of this experiment is to superpose a fixed frequency signal (gabor) with a fixed frequency noise and change their constrasts to see how that affects how we see the whole image. The expected outcome is to see the *masking* phenomenon, in which the noise masks the signal and it can't be seen.

# %% [markdown]
# ## Importing libraries

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import get_file

from perceptnet.networks import PerceptNet

# %% [markdown]
# ## Loading the images

# %%
path_tests = '/media/disk/users/paherca/Perceptual_tests'
path_nn = 'gabors_without_noise_achromatic.npy'
path_lf = 'gabors_noise_diff_freq_low_freq.npy'
path_hf = 'gabors_noise_diff_freq_high_freq.npy'

# %%
gabor_nn = np.load(os.path.join(path_tests, path_nn))
gabor_lf = np.load(os.path.join(path_tests, path_lf))
gabor_hf = np.load(os.path.join(path_tests, path_hf))

gabor_nn.shape, gabor_lf.shape, gabor_hf.shape
# Out:
# ((256, 256, 3, 5, 8), (256, 256, 3, 8, 5), (256, 256, 3, 8, 5))

# %% [markdown]
# These noise files have (256,256,3) images created with 5 different frequencies for the noise (5th dim). The 4th dim represents changes in the stimulous contrast.
# While the gabors files have (256,256,3) images with 8 different contrasts (5th dim) and 4 different frequencies (4th dim).
#
# To be able to pass the through our model in a more confortable way we could transpose the so that the contrasts act as "batch dims".

# %%
fig, ax = plt.subplots(*gabor_nn.shape[-2:], figsize=(10,10))
for i in range(gabor_nn.shape[-2]):
    for j in range(gabor_nn.shape[-1]):
        ax[i][j].imshow(gabor_nn[:,:,:,i,j])
        ax[i][j].axis('off')
plt.show()

# %%
fig, ax = plt.subplots(*gabor_lf.shape[-2:], figsize=(10,10))
for i in range(gabor_lf.shape[-2]):
    for j in range(gabor_lf.shape[-1]):
        ax[i][j].imshow(gabor_lf[:,:,:,i,j])
        ax[i][j].axis('off')
plt.show()

# %%
freq_low = 4
freq_high = 16
freqs = np.array([2, 4, 8, 16, 32])
# delta_freq = [1, 2, 4, 8, 16]
delta_freq_low = np.abs(freqs-freq_low)
delta_freq_high = np.abs(freqs-freq_high)
contrasts = 0.7*np.linspace(0, 0.15, 8)
# contrasts_noises = 0.4*np.array([0, 0.1, 0.2, 0.3, 0.4])
contrasts_noises = 0.12

# %%
gabor_nn = gabor_nn.transpose(3,4,0,1,2)
gabor_lf = gabor_lf.transpose(4,3,0,1,2)
gabor_hf = gabor_hf.transpose(4,3,0,1,2)

gabor_nn.shape, gabor_lf.shape, gabor_hf.shape
# Out:
# ((5, 8, 256, 256, 3), (5, 8, 256, 256, 3), (5, 8, 256, 256, 3))

# %%
fig, ax = plt.subplots(*gabor_lf.shape[:2], figsize=(10,10))
for i in range(gabor_lf.shape[0]):
    for j in range(gabor_lf.shape[1]):
        ax[i][j].imshow(gabor_lf[i,j,:,:,:])
        ax[i][j].axis('off')
plt.show()

# %% [markdown]
# We can plot the data to make sure everything is correct:

# %%
for i in range(len(freqs)):
    fig, ax = plt.subplots(1, 8, figsize=(10,2))
    for j,img in enumerate(gabor_nn[i]):
        ax[j].imshow(img)
        ax[j].axis('off')
    plt.suptitle(f'Frequency (Signal): {freqs[i]:.2f}')
    plt.show()

# %%
for i in range(len(freqs)):
    fig, ax = plt.subplots(1, 8, figsize=(10,2))
    for j,img in enumerate(gabor_lf[i]):
        ax[j].imshow(img)
        ax[j].axis('off')
    plt.suptitle(f'Frequency (Noise): {freqs[i]:.2f}')
    plt.show()

# %%
for i in range(len(freqs)):
    fig, ax = plt.subplots(1, 8, figsize=(10,2))
    for j,img in enumerate(gabor_hf[i]):
        ax[j].imshow(img)
        ax[j].axis('off')
    plt.suptitle(f'Frequency (Noise): {freqs[i]:.2f}')
    plt.show()

# %% [markdown]
# ## Passing the inputs through the network

# %%
weights_path = get_file(fname='perceptnet_rgb.h5',
                        origin='https://github.com/Jorgvt/perceptnet/releases/download/Weights/final_model_rgb.h5')

# %%
model = PerceptNet(kernel_initializer='ones', gdn_kernel_size=1, learnable_undersampling=False)
model.build(input_shape=(None, 384, 512, 3))
model.load_weights(weights_path)
# Out:
# 2022-05-09 21:11:31.471209: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5435 MB memory:  -> device: 0, name: NVIDIA GeForce GTX TITAN Black, pci bus id: 0000:83:00.0, compute capability: 3.5

# %% [markdown]
# We can do the processing on the fly to save memory:
#
# > The output of each image must be compared to the output produced by the image where the signal's contrast is 0, so we will have to always compare to the first element in each batch.

# %%
def get_readouts(model, imgs):
    ## Pass the through the model
    outputs = model.predict(imgs)

    ## Get the readouts as the distance to the lowest freq image
    readouts = (outputs-outputs[0])**2
    readouts = np.sqrt(np.sum(readouts.reshape(imgs.shape[0],-1), axis=-1))
    
    ## Return readouts
    return readouts

# %%
def plot_results(results, color='k'):
    alphas = np.linspace(0.2,1,len(results))
    markers = ['o', '*', '^', 's', '.']
    for i, (c_noise, readouts) in enumerate(results.items()):
        plt.plot(contrasts, readouts, color, alpha=alphas[i], marker=markers[i], label=f'Freq (Noise) = {c_noise:.2f}')
        plt.xlabel('Contrast (Signal)')
        plt.ylabel('Visibility')

# %%
def plot_results_2(results, color='k'):
    alphas = np.linspace(0.2,1,len(results))
    markers = ['o', '*', '^', 's', '.']
    for i, (delta_f, readouts) in enumerate(results.items()):
        plt.plot(contrasts, readouts, color, alpha=alphas[i], marker=markers[i], label=f'Delta Freq = {delta_f:.2f}')
        plt.xlabel('Contrast (Signal)')
        plt.ylabel('Visibility')

# %%
results_nn = {}
for c_noise, batch in zip(freqs, gabor_nn):
    results_nn[c_noise] = get_readouts(model, batch)

# %%
results_lf = {}
for c_noise, batch in zip(delta_freq_low, gabor_lf):
    results_lf[c_noise] = get_readouts(model, batch)

# %%
results_hf = {}
for c_noise, batch in zip(delta_freq_high, gabor_hf):
    results_hf[c_noise] = get_readouts(model, batch)

# %% [markdown]
# Plot the results:

# %%
plt.figure(figsize=(15,4))

plt.subplot(1,3,1)
plt.title('No Noise')
plot_results(results_nn)
plt.legend()

plt.subplot(1,3,2)
plt.title('Low Frequency')
plot_results_2(results_lf)
plt.plot(contrasts, results_nn[freq_low], 'r', label='No Noise')
plt.legend()

plt.subplot(1,3,3)
plt.title('High Frequency')
plot_results_2(results_hf)
plt.plot(contrasts, results_nn[freq_high], 'r', label='No Noise')
plt.legend()

plt.show()
